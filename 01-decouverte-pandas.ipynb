# %%
import pandas as pd

donnees = {
    "jour": ["lundi", "mardi", "mercredi", "jeudi", "vendredi", "samedi", "dimanche"],
    "conso_gw": [72, 74, 73, 75, 71, 61, 58],
    "temperature": [4, 3, 5, 2, 6, 7, 8],
    "type_jour": ["semaine", "semaine", "semaine", "semaine", "semaine", "weekend", "weekend"],
}

df = pd.DataFrame(donnees)
df
# Out:
#        jour  conso_gw  temperature type_jour
# 0     lundi        72            4   semaine
# 1     mardi        74            3   semaine
# 2  mercredi        73            5   semaine
# 3     jeudi        75            2   semaine
# 4  vendredi        71            6   semaine
# 5    samedi        61            7   weekend
# 6  dimanche        58            8   weekend

# %%
df.head()
# Out:
#        jour  conso_gw  temperature type_jour
# 0     lundi        72            4   semaine
# 1     mardi        74            3   semaine
# 2  mercredi        73            5   semaine
# 3     jeudi        75            2   semaine
# 4  vendredi        71            6   semaine

# %%
df.tail()
# Out:
#        jour  conso_gw  temperature type_jour
# 2  mercredi        73            5   semaine
# 3     jeudi        75            2   semaine
# 4  vendredi        71            6   semaine
# 5    samedi        61            7   weekend
# 6  dimanche        58            8   weekend

# %%
df.describe()
# Out:
#         conso_gw  temperature
# count   7.000000     7.000000
# mean   69.142857     5.000000
# std     6.768273     2.160247
# min    58.000000     2.000000
# 25%    66.000000     3.500000
# 50%    72.000000     5.000000
# 75%    73.500000     6.500000
# max    75.000000     8.000000

# %%
df['conso_gw']
# Out:
# 0    72
# 1    74
# 2    73
# 3    75
# 4    71
# 5    61
# 6    58
# Name: conso_gw, dtype: int64

# %%
df[df['conso_gw']>72]
# Out:
#        jour  conso_gw  temperature type_jour
# 1     mardi        74            3   semaine
# 2  mercredi        73            5   semaine
# 3     jeudi        75            2   semaine

# %%
df['conso_mw']=df['conso_gw']*1000

# %%
df['conso_mw']
# Out:
# 0    72000
# 1    74000
# 2    73000
# 3    75000
# 4    71000
# 5    61000
# 6    58000
# Name: conso_mw, dtype: int64

# %%
df.groupby('type_jour')['conso_jour'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.groupby('type_jour')['conso_jour'].mean()
#
# File D:\Projets\conso-electrique-france\.venv\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File D:\Projets\conso-electrique-france\.venv\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# --> 228         raise KeyError(f"Column not found: {key}")
#     229     ndim = self.obj[key].ndim
#     230     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: conso_jour'

# %%
df.groupby('type_jour')['conso_gw'].mean()
# Out:
# type_jour
# semaine    73.0
# weekend    59.5
# Name: conso_gw, dtype: float64

# %%
df.plot(x="jour", y="conso_gw")
# Out:
# <Axes: xlabel='jour'>

# %%
df.plot(x="jour", y="temperature")
# Out:
# <Axes: xlabel='jour'>
