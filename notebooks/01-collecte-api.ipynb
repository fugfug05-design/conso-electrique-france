# %% [markdown]
# # Exploration de l'API éco2mix

# %% [markdown]
# Objectif : comprendre la structure de l'API de l'ODRE avant d'écrire le script de collecte.

# %%
import requests

url = "https://odre.opendatasoft.com/api/explore/v2.1/catalog/datasets/eco2mix-national-cons-def/records"
reponse = requests.get(url, params={"limit": 5})
reponse.status_code
# Out:
# 200

# %%
donnees = reponse.json()

# %%
donnees.keys()
# Out:
# dict_keys(['total_count', 'results'])

# %%
donnees['total_count']
# Out:
# 502464

# %%
donnees
# Out:
# {'total_count': 502464,
#  'results': [{'perimetre': 'France',
#    'nature': 'Données définitives',
#    'date': '2013-05-16',
#    'heure': '11:30',
#    'date_heure': '2013-05-16T09:30:00+00:00',
#    'consommation': 59510,
#    'prevision_j1': 58800,
#    'prevision_j': 59600,
#    'fioul': 450,
#    'charbon': 1871,
#    'gaz': 1182,
#    'nucleaire': 45899,
#    'eolien': 493,
#    'solaire': 1184,
#    'hydraulique': 12709,
#    'pompage': -8,
#    'bioenergies': 656,
#    'ech_physiques': -4929,
#    'taux_co2': 49,
#    'ech_comm_angleterre': -1500,
#    'ech_comm_espagne': -413,
#    'ech_comm_italie': -2466,
#    'ech_comm_suisse': -117,
#    'ech_comm_allemagne_belgique': '-286',
#    'fioul_tac': 136,
#    'fioul_cogen': 206,
#    'fioul_autres': 107,
#    'gaz_tac': -1,
#    'gaz_cogen': '459',
#    'gaz_ccg': 634,
#    'gaz_autres': 89,
#    'hydraulique_fil_eau_eclusee': 7758,
#    'hydraulique_lacs': 3259,
#    'hydraulique_step_turbinage': 1691,
#    'bioenergies_dechets': 354,
#    'bioenergies_biomasse': 150,
#    'bioenergies_biogaz': 151},
#   {'perimetre': 'France',
#    'nature': 'Données définitives',
#    'date': '2013-05-16',
#    'heure': '12:15',
#    'date_heure': '2013-05-16T10:15:00+00:00',
#    'consommation': None,
#    'prevision_j1': 58850,
#    'prevision_j': 59750,
#    'fioul': None,
#    'charbon': None,
#    'gaz': None,
#    'nucleaire': None,
#    'eolien': None,
#    'solaire': None,
#    'hydraulique': None,
#    'pompage': None,
#    'bioenergies': None,
#    'ech_physiques': None,
#    'taux_co2': None,
#    'ech_comm_angleterre': None,
#    'ech_comm_espagne': None,
#    'ech_comm_italie': None,
#    'ech_comm_suisse': None,
#    'ech_comm_allemagne_belgique': None,
#    'fioul_tac': None,
#    'fioul_cogen': None,
#    'fioul_autres': None,
#    'gaz_tac': None,
#    'gaz_cogen': None,
#    'gaz_ccg': None,
#    'gaz_autres': None,
#    'hydraulique_fil_eau_eclusee': None,
#    'hydraulique_lacs': None,
#    'hydraulique_step_turbinage': None,
#    'bioenergies_dechets': None,
#    'bioenergies_biomasse': None,
#    'bioenergies_biogaz': None},
#   {'perimetre': 'France',
#    'nature': 'Données définitives',
#    'date': '2013-05-16',
#    'heure': '12:30',
#    'date_heure': '2013-05-16T10:30:00+00:00',
#    'consommation': 59351,
#    'prevision_j1': 58400,
#    'prevision_j': 59300,
#    'fioul': 430,
#    'charbon': 1899,
#    'gaz': 1035,
#    'nucleaire': 45856,
#    'eolien': 461,
#    'solaire': 1377,
#    'hydraulique': 13001,
#    'pompage': -60,
#    'bioenergies': 655,
#    'ech_physiques': -5306,
#    'taux_co2': 48,
#    'ech_comm_angleterre': -1500,
#    'ech_comm_espagne': -934,
#    'ech_comm_italie': -2466,
#    'ech_comm_suisse': 17,
#    'ech_comm_allemagne_belgique': '-315',
#    'fioul_tac': 115,
#    'fioul_cogen': 206,
#    'fioul_autres': 108,
#    'gaz_tac': -1,
#    'gaz_cogen': '393',
#    'gaz_ccg': 554,
#    'gaz_autres': 89,
#    'hydraulique_fil_eau_eclusee': 7799,
#    'hydraulique_lacs': 3224,
#    'hydraulique_step_turbinage': 1977,
#    'bioenergies_dechets': 353,
#    'bioenergies_biomasse': 150,
#    'bioenergies_biogaz': 151},
#   {'perimetre': 'France',
#    'nature': 'Données définitives',
#    'date': '2013-05-16',
#    'heure': '17:15',
#    'date_heure': '2013-05-16T15:15:00+00:00',
#    'consommation': None,
#    'prevision_j1': 51700,
#    'prevision_j': 52500,
#    'fioul': None,
#    'charbon': None,
#    'gaz': None,
#    'nucleaire': None,
#    'eolien': None,
#    'solaire': None,
#    'hydraulique': None,
#    'pompage': None,
#    'bioenergies': None,
#    'ech_physiques': None,
#    'taux_co2': None,
#    'ech_comm_angleterre': None,
#    'ech_comm_espagne': None,
#    'ech_comm_italie': None,
#    'ech_comm_suisse': None,
#    'ech_comm_allemagne_belgique': None,
#    'fioul_tac': None,
#    'fioul_cogen': None,
#    'fioul_autres': None,
#    'gaz_tac': None,
#    'gaz_cogen': None,
#    'gaz_ccg': None,
#    'gaz_autres': None,
#    'hydraulique_fil_eau_eclusee': None,
#    'hydraulique_lacs': None,
#    'hydraulique_step_turbinage': None,
#    'bioenergies_dechets': None,
#    'bioenergies_biomasse': None,
#    'bioenergies_biogaz': None},
#   {'perimetre': 'France',
#    'nature': 'Données définitives',
#    'date': '2013-05-16',
#    'heure': '18:15',
#    'date_heure': '2013-05-16T16:15:00+00:00',
#    'consommation': None,
#    'prevision_j1': 52600,
#    'prevision_j': 53000,
#    'fioul': None,
#    'charbon': None,
#    'gaz': None,
#    'nucleaire': None,
#    'eolien': None,
#    'solaire': None,
#    'hydraulique': None,
#    'pompage': None,
#    'bioenergies': None,
#    'ech_physiques': None,
#    'taux_co2': None,
#    'ech_comm_angleterre': None,
#    'ech_comm_espagne': None,
#    'ech_comm_italie': None,
#    'ech_comm_suisse': None,
#    'ech_comm_allemagne_belgique': None,
#    'fioul_tac': None,
#    'fioul_cogen': None,
#    'fioul_autres': None,
#    'gaz_tac': None,
#    'gaz_cogen': None,
#    'gaz_ccg': None,
#    'gaz_autres': None,
#    'hydraulique_fil_eau_eclusee': None,
#    'hydraulique_lacs': None,
#    'hydraulique_step_turbinage': None,
#    'bioenergies_dechets': None,
#    'bioenergies_biomasse': None,
#    'bioenergies_biogaz': None}]}

# %%
donnees['results'][0]
# Out:
# {'perimetre': 'France',
#  'nature': 'Données définitives',
#  'date': '2013-05-16',
#  'heure': '11:30',
#  'date_heure': '2013-05-16T09:30:00+00:00',
#  'consommation': 59510,
#  'prevision_j1': 58800,
#  'prevision_j': 59600,
#  'fioul': 450,
#  'charbon': 1871,
#  'gaz': 1182,
#  'nucleaire': 45899,
#  'eolien': 493,
#  'solaire': 1184,
#  'hydraulique': 12709,
#  'pompage': -8,
#  'bioenergies': 656,
#  'ech_physiques': -4929,
#  'taux_co2': 49,
#  'ech_comm_angleterre': -1500,
#  'ech_comm_espagne': -413,
#  'ech_comm_italie': -2466,
#  'ech_comm_suisse': -117,
#  'ech_comm_allemagne_belgique': '-286',
#  'fioul_tac': 136,
#  'fioul_cogen': 206,
#  'fioul_autres': 107,
#  'gaz_tac': -1,
#  'gaz_cogen': '459',
#  'gaz_ccg': 634,
#  'gaz_autres': 89,
#  'hydraulique_fil_eau_eclusee': 7758,
#  'hydraulique_lacs': 3259,
#  'hydraulique_step_turbinage': 1691,
#  'bioenergies_dechets': 354,
#  'bioenergies_biomasse': 150,
#  'bioenergies_biogaz': 151}

# %%
donnees["results"][0].keys()
# Out:
# dict_keys(['perimetre', 'nature', 'date', 'heure', 'date_heure', 'consommation', 'prevision_j1', 'prevision_j', 'fioul', 'charbon', 'gaz', 'nucleaire', 'eolien', 'solaire', 'hydraulique', 'pompage', 'bioenergies', 'ech_physiques', 'taux_co2', 'ech_comm_angleterre', 'ech_comm_espagne', 'ech_comm_italie', 'ech_comm_suisse', 'ech_comm_allemagne_belgique', 'fioul_tac', 'fioul_cogen', 'fioul_autres', 'gaz_tac', 'gaz_cogen', 'gaz_ccg', 'gaz_autres', 'hydraulique_fil_eau_eclusee', 'hydraulique_lacs', 'hydraulique_step_turbinage', 'bioenergies_dechets', 'bioenergies_biomasse', 'bioenergies_biogaz'])

# %%
reponse = requests.get(url, params={"limit": 1, "order_by": "date_heure desc"})

# %%
reponse.json()
# Out:
# {'total_count': 502464,
#  'results': [{'perimetre': 'France',
#    'nature': 'Données consolidées',
#    'date': '2026-04-30',
#    'heure': '23:45',
#    'date_heure': '2026-04-30T21:45:00+00:00',
#    'consommation': None,
#    'prevision_j1': 43600,
#    'prevision_j': 43850,
#    'fioul': None,
#    'charbon': None,
#    'gaz': None,
#    'nucleaire': None,
#    'eolien': None,
#    'solaire': None,
#    'hydraulique': None,
#    'pompage': None,
#    'bioenergies': None,
#    'ech_physiques': None,
#    'taux_co2': None,
#    'ech_comm_angleterre': -3028,
#    'ech_comm_espagne': -2775,
#    'ech_comm_italie': -4080,
#    'ech_comm_suisse': -3200,
#    'ech_comm_allemagne_belgique': '-5912',
#    'fioul_tac': None,
#    'fioul_cogen': None,
#    'fioul_autres': None,
#    'gaz_tac': None,
#    'gaz_cogen': None,
#    'gaz_ccg': None,
#    'gaz_autres': None,
#    'hydraulique_fil_eau_eclusee': None,
#    'hydraulique_lacs': None,
#    'hydraulique_step_turbinage': None,
#    'bioenergies_dechets': None,
#    'bioenergies_biomasse': None,
#    'bioenergies_biogaz': None}]}

# %% [markdown]
# La conso du dernier jour est vide, peut être parceque le jour n'est pas fini
